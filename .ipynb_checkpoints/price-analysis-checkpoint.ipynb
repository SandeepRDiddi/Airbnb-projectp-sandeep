# %% [markdown]
# ## Import Libraries and Data

# %%
#Import required libraries 

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import statsmodels.formula.api as smf
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from sklearn import ensemble
# %matplotlib inline

# %%
# Read the clean data which was processed durning the Data Engineering Phase
data_dummies_ABB = pd.read_csv('cleaned-listings-dummies.csv')
data_list_ABB = pd.read_csv('cleaned-listings-base.csv')

# %% [markdown]
# ### Initial Price Regression
#
# Below we will use OLS method of regression with all IDV's ( Independent Variable). Variables which were exluded were either almost  NaN, or only contained a single value for >90% of listing. This strategy was discussed in Udactity course on when to reject the variables and when not to. So the same methodology was used here

# %%
simple_reg = 'price ~ host_response_rate + accommodates + guests_included + bathrooms + bedrooms + beds + number_of_reviews + review_scores_rating + review_scores_accuracy + review_scores_cleanliness + review_scores_checkin + review_scores_communication + review_scores_location + review_scores_value + host_is_superhost + neighbourhood_Ballard  + neighbourhood_Cascade  + neighbourhood_Delridge + neighbourhood_Downtown + neighbourhood_Interbay + neighbourhood_Magnolia + neighbourhood_Northgate + property_type_Apartment  + property_type_Condominium + property_type_House + property_type_Loft + property_type_Townhouse + neighbourhood_Beacon_Hill + neighbourhood_Capitol_Hill + neighbourhood_Central_Area + neighbourhood_Lake_City + neighbourhood_Other_neighborhoods + neighbourhood_Queen_Anne + neighbourhood_Rainier_Valley + neighbourhood_Seward_Park + neighbourhood_University_District + neighbourhood_West_Seattle + property_type_Bed_Breakfast + room_type_Entire_home_apt + room_type_Private_room + room_type_Shared_room'

regression_pred = smf.ols(formula=simple_reg, data=data_dummies_ABB).fit()
regression_pred.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.596
# Model:                            OLS   Adj. R-squared:                  0.591
# Method:                 Least Squares   F-statistic:                     142.0
# Date:                Tue, 08 Jun 2021   Prob (F-statistic):               0.00
# Time:                        13:08:53   Log-Likelihood:                -20192.
# No. Observations:                3704   AIC:                         4.046e+04
# Df Residuals:                    3665   BIC:                         4.071e+04
# Df Model:                          38
# Covariance Type:            nonrobust
# =====================================================================================================
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                           -44.2589     15.138     -2.924      0.003     -73.940     -14.578
# host_response_rate                   -0.1528      0.087     -1.762      0.078      -0.323       0.017
# accommodates                          7.5362      1.136      6.635      0.000       5.309       9.763
# guests_included                       3.5307      0.851      4.147      0.000       1.862       5.200
# bathrooms                            28.1296      2.163     13.007      0.000      23.889      32.370
# bedrooms                             31.8643      1.984     16.064      0.000      27.975      35.753
# beds                                  1.2308      1.724      0.714      0.475      -2.149       4.611
# number_of_reviews                    -0.1495      0.027     -5.516      0.000      -0.203      -0.096
# review_scores_rating                  0.6396      0.257      2.486      0.013       0.135       1.144
# review_scores_accuracy                2.7737      1.977      1.403      0.161      -1.102       6.649
# review_scores_cleanliness             2.4117      1.732      1.393      0.164      -0.983       5.807
# review_scores_checkin                -0.5911      2.445     -0.242      0.809      -5.385       4.203
# review_scores_communication           0.3139      2.624      0.120      0.905      -4.830       5.458
# review_scores_location                6.2686      1.910      3.283      0.001       2.525      10.013
# review_scores_value                  -8.8816      1.987     -4.471      0.000     -12.777      -4.987
# host_is_superhost                     7.4143      2.484      2.985      0.003       2.544      12.285
# neighbourhood_Ballard                -7.5149      4.116     -1.826      0.068     -15.585       0.555
# neighbourhood_Cascade                23.2742      6.209      3.749      0.000      11.101      35.447
# neighbourhood_Delridge              -23.9950      6.344     -3.782      0.000     -36.433     -11.557
# neighbourhood_Downtown               32.1109      3.359      9.559      0.000      25.525      38.697
# neighbourhood_Interbay                8.6161     17.041      0.506      0.613     -24.794      42.027
# neighbourhood_Magnolia               16.7352      7.138      2.345      0.019       2.740      30.730
# neighbourhood_Northgate             -30.3082      6.571     -4.613      0.000     -43.191     -17.426
# property_type_Apartment             -18.2208      3.629     -5.021      0.000     -25.336     -11.106
# property_type_Condominium           -13.1097      6.180     -2.121      0.034     -25.226      -0.993
# property_type_House                 -12.3470      3.603     -3.426      0.001     -19.412      -5.282
# property_type_Loft                   15.8069      8.341      1.895      0.058      -0.547      32.161
# property_type_Townhouse             -18.7985      5.685     -3.307      0.001     -29.944      -7.653
# neighbourhood_Beacon_Hill           -17.4657      5.475     -3.190      0.001     -28.200      -6.732
# neighbourhood_Capitol_Hill           15.5252      3.118      4.979      0.000       9.412      21.639
# neighbourhood_Central_Area           -5.7719      3.387     -1.704      0.088     -12.413       0.870
# neighbourhood_Lake_City             -14.1096      6.872     -2.053      0.040     -27.582      -0.637
# neighbourhood_Other_neighborhoods   -10.8097      2.711     -3.988      0.000     -16.124      -5.495
# neighbourhood_Queen_Anne             23.9546      3.771      6.352      0.000      16.561      31.348
# neighbourhood_Rainier_Valley        -23.4527      4.744     -4.944      0.000     -32.753     -14.152
# neighbourhood_Seward_Park           -19.8702      8.292     -2.396      0.017     -36.127      -3.613
# neighbourhood_University_District   -10.1510      5.186     -1.957      0.050     -20.319       0.017
# neighbourhood_West_Seattle           -1.0262      4.342     -0.236      0.813      -9.539       7.487
# property_type_Bed_Breakfast           2.4102      8.701      0.277      0.782     -14.650      19.470
# room_type_Entire_home_apt            17.9092      5.563      3.219      0.001       7.003      28.816
# room_type_Private_room              -15.8808      5.427     -2.926      0.003     -26.520      -5.241
# room_type_Shared_room               -46.2874      6.408     -7.223      0.000     -58.852     -33.723
# ==============================================================================
# Omnibus:                     2937.782   Durbin-Watson:                   1.995
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           156790.589
# Skew:                           3.338   Prob(JB):                         0.00
# Kurtosis:                      34.166   Cond. No.                     7.28e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.34e-26. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %% [markdown]
#  R-squared observed above .581, which indicated variables has least explanations about the Dependent Variable
#
# Features like bathrooms, bedrooms, and number of guests have strong positive relationships with price and need to be only considered to see how they perfomr in coming steps

# %% [markdown]
# ## EDA

# %% [markdown]
# ### Heatmap to Display the Co-Relations with other Independent variables

# %%
fig, ax = plt.subplots(figsize=(15,10)) 
sns.heatmap(data_list_ABB.corr(),annot=True, ax = ax);

# %% [markdown]
# We shall pick up variables that are correlated with price

# %% [markdown]
# ## Prices Overview

# %%
#Profile the data 
#!pip install pandas-profiling
#pip install https://github.com/pandas-profiling/pandas-profiling/archive/master.zip
from pandas_profiling import ProfileReport

profile = ProfileReport(data_list_ABB, title="Pandas Profiling Report")
profile = ProfileReport(data_list_ABB, title="Pandas Profiling Report", explorative=True)
profile.to_widgets()


#Min Price of Price 
#Minimum
#20

#Maximum
#999

#Mean
#128.0261879


#Profiling gives the entire stats about the data so there is no need to plot multi line codes of different summar and or the 
#Corelations
# Out:
# Summarize dataset:   0%|          | 0/34 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render widgets:   0%|          | 0/1 [00:00<?, ?it/s]
# VBox(children=(Tab(children=(Tab(children=(GridBox(children=(VBox(children=(GridspecLayout(children=(HTML(valu…

# %% [markdown]
# ## Property Type and Price

# %% [markdown]
# Popular Airbnb properties check

# %%
# neighborhood average price comparison 
plt.figure(figsize=(15,10))
base_color = sns.color_palette()[0]
property_type_price = data_list_ABB.groupby(['property_type']).mean().price.sort_values(ascending=False)
property_type_price_pdf = pd.DataFrame(property_type_price)
property_type_price_pdf = property_type_price_pdf.reset_index()
sns.barplot(y="price", x="property_type", data=property_type_price_pdf,color = base_color)
plt.title("Average Listing Price per Property Type")
plt.xlabel("Property Type")
plt.ylabel("Average Price in US Dollars")
# Out:
# Text(0, 0.5, 'Average Price in US Dollars')

# %% [markdown]
# ## Based on the Char above we can consulde that Condo prices are highest on Air BNB when compared with others

# %% [markdown]
# ## Neighborhood and Price Comparision Chart

# %%
# neighborhood average price comparison 
plt.figure(figsize=(12,8))
base_color = sns.color_palette()[0]
prices_by_neighbourhood = data_list_ABB.groupby(['neighbourhood']).mean().price.sort_values(ascending=False)
neighbourhood_prices_df = pd.DataFrame(prices_by_neighbourhood)
neighbourhood_prices_df = neighbourhood_prices_df.reset_index()
sns.barplot(x="neighbourhood",y="price", data=neighbourhood_prices_df,color = base_color)
plt.xticks(rotation = 90)
plt.title("Average Listing Price per Neighborhood")
plt.xlabel("Neighborhood")
plt.ylabel("Average Price in US Dollars")
# Out:
# Text(0, 0.5, 'Average Price in US Dollars')

# %% [markdown]
# ## Magnolia stands out with an average price of nearly 175 USD

# %% [markdown]
# ## Number of Reviews in the data set

# %% [markdown]
# ## Does Review play any important role in the pricing of the property on the data set, lets check that too

# %%
#Filter properties who have more than 3 reviews only , this is done to capture the right property for Analysis
review_data_G3 = data_dummies_ABB[data_dummies_ABB.number_of_reviews > 3]

# %% [markdown]
# ## Airbnb Rating Regression

# %%
host_ratng = 'review_scores_rating ~ host_response_rate + accommodates + guests_included + bathrooms + bedrooms + beds + number_of_reviews + price + review_scores_accuracy + review_scores_cleanliness + review_scores_checkin + review_scores_communication + review_scores_location + review_scores_value + host_is_superhost + neighbourhood_Ballard  + neighbourhood_Cascade  + neighbourhood_Delridge + neighbourhood_Downtown + neighbourhood_Interbay + neighbourhood_Magnolia + neighbourhood_Northgate + property_type_Apartment  + property_type_Condominium + property_type_House + property_type_Loft + property_type_Townhouse + neighbourhood_Beacon_Hill + neighbourhood_Capitol_Hill + neighbourhood_Central_Area + neighbourhood_Lake_City + neighbourhood_Other_neighborhoods + neighbourhood_Queen_Anne + neighbourhood_Rainier_Valley + neighbourhood_Seward_Park + neighbourhood_University_District + neighbourhood_West_Seattle + property_type_Bed_Breakfast + room_type_Entire_home_apt + room_type_Private_room + room_type_Shared_room'

df_ratng = smf.ols(formula=host_ratng, data=review_data_G3).fit()
df_ratng.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              OLS Regression Results
# ================================================================================
# Dep. Variable:     review_scores_rating   R-squared:                       0.719
# Model:                              OLS   Adj. R-squared:                  0.715
# Method:                   Least Squares   F-statistic:                     160.7
# Date:                  Tue, 08 Jun 2021   Prob (F-statistic):               0.00
# Time:                          14:47:36   Log-Likelihood:                -5878.2
# No. Observations:                  2424   AIC:                         1.183e+04
# Df Residuals:                      2385   BIC:                         1.206e+04
# Df Model:                            38
# Covariance Type:              nonrobust
# =====================================================================================================
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                            -0.4947      1.052     -0.470      0.638      -2.557       1.568
# host_response_rate                    0.0064      0.006      1.128      0.260      -0.005       0.018
# accommodates                         -0.0249      0.071     -0.353      0.724      -0.163       0.114
# guests_included                      -0.0544      0.054     -1.007      0.314      -0.160       0.052
# bathrooms                             0.1837      0.133      1.379      0.168      -0.077       0.445
# bedrooms                              0.0582      0.128      0.456      0.648      -0.192       0.308
# beds                                 -0.0540      0.105     -0.513      0.608      -0.261       0.153
# number_of_reviews                    -0.0028      0.001     -1.999      0.046      -0.006   -5.38e-05
# price                                 0.0036      0.001      3.474      0.001       0.002       0.006
# review_scores_accuracy                1.6423      0.135     12.149      0.000       1.377       1.907
# review_scores_cleanliness             2.0050      0.108     18.523      0.000       1.793       2.217
# review_scores_checkin                 1.3617      0.169      8.073      0.000       1.031       1.693
# review_scores_communication           1.7527      0.177      9.930      0.000       1.407       2.099
# review_scores_location                0.9312      0.120      7.782      0.000       0.697       1.166
# review_scores_value                   2.1203      0.125     16.977      0.000       1.875       2.365
# host_is_superhost                     0.6915      0.136      5.085      0.000       0.425       0.958
# neighbourhood_Ballard                -0.4465      0.243     -1.840      0.066      -0.922       0.029
# neighbourhood_Cascade                 0.1534      0.411      0.374      0.709      -0.652       0.959
# neighbourhood_Delridge                0.5707      0.379      1.505      0.133      -0.173       1.315
# neighbourhood_Downtown                0.0233      0.211      0.110      0.912      -0.390       0.437
# neighbourhood_Interbay                1.2777      1.069      1.195      0.232      -0.818       3.374
# neighbourhood_Magnolia               -0.1886      0.464     -0.406      0.685      -1.099       0.722
# neighbourhood_Northgate              -0.6410      0.421     -1.522      0.128      -1.467       0.185
# property_type_Apartment              -0.3262      0.242     -1.348      0.178      -0.801       0.148
# property_type_Condominium            -0.1307      0.436     -0.300      0.764      -0.986       0.724
# property_type_House                  -0.2324      0.241     -0.963      0.336      -0.706       0.241
# property_type_Loft                   -0.3489      0.531     -0.657      0.511      -1.391       0.693
# property_type_Townhouse               0.0226      0.395      0.057      0.954      -0.752       0.797
# neighbourhood_Beacon_Hill             0.4662      0.317      1.468      0.142      -0.156       1.089
# neighbourhood_Capitol_Hill           -0.1138      0.197     -0.579      0.563      -0.499       0.272
# neighbourhood_Central_Area            0.3927      0.206      1.911      0.056      -0.010       0.796
# neighbourhood_Lake_City              -0.8986      0.419     -2.146      0.032      -1.720      -0.078
# neighbourhood_Other_neighborhoods    -0.1254      0.170     -0.736      0.462      -0.460       0.209
# neighbourhood_Queen_Anne             -0.3400      0.234     -1.454      0.146      -0.798       0.118
# neighbourhood_Rainier_Valley          0.5191      0.285      1.819      0.069      -0.041       1.079
# neighbourhood_Seward_Park            -0.2085      0.470     -0.444      0.657      -1.130       0.713
# neighbourhood_University_District    -0.8332      0.341     -2.445      0.015      -1.501      -0.165
# neighbourhood_West_Seattle           -0.1021      0.267     -0.383      0.702      -0.626       0.421
# property_type_Bed_Breakfast           0.5209      0.532      0.980      0.327      -0.522       1.563
# room_type_Entire_home_apt            -0.5175      0.382     -1.356      0.175      -1.266       0.231
# room_type_Private_room               -0.3669      0.372     -0.987      0.324      -1.096       0.362
# room_type_Shared_room                 0.3897      0.443      0.880      0.379      -0.479       1.258
# ==============================================================================
# Omnibus:                      482.602   Durbin-Watson:                   2.018
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3943.398
# Skew:                          -0.707   Prob(JB):                         0.00
# Kurtosis:                       9.086   Cond. No.                     6.61e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.69e-26. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %% [markdown]
# ## Predicting Price using Regression

# %%
data_dummies_ABB.describe()
# Out:
#                  id       host_id  host_response_rate  host_is_superhost  \
# count  3.705000e+03  3.705000e+03         3705.000000        3705.000000
# mean   5.586811e+06  1.590177e+07           94.847728           0.203779
# std    2.937057e+06  1.458411e+07           11.080400           0.402861
# min    4.291000e+03  4.193000e+03           17.000000           0.000000
# 25%    3.312406e+06  3.365488e+06           94.886798           0.000000
# 50%    6.156470e+06  1.072290e+07          100.000000           0.000000
# 75%    8.050232e+06  2.600215e+07          100.000000           0.000000
# max    1.034016e+07  5.320861e+07          100.000000           1.000000
#
#        accommodates    bathrooms     bedrooms         beds        price  \
# count   3705.000000  3705.000000  3705.000000  3705.000000  3704.000000
# mean       3.366262     1.261134     1.319028     1.738192   128.026188
# std        1.984822     0.578153     0.885586     1.137193    88.700893
# min        1.000000     0.000000     0.000000     1.000000    20.000000
# 25%        2.000000     1.000000     1.000000     1.000000    75.000000
# 50%        3.000000     1.000000     1.000000     1.000000   100.000000
# 75%        4.000000     1.000000     2.000000     2.000000   150.000000
# max       16.000000     8.000000     7.000000    15.000000   999.000000
#
#        guests_included  ...  neighbourhood_West_Seattle  \
# count      3705.000000  ...                 3705.000000
# mean          1.682321  ...                    0.053171
# std           1.322171  ...                    0.224405
# min           0.000000  ...                    0.000000
# 25%           1.000000  ...                    0.000000
# 50%           1.000000  ...                    0.000000
# 75%           2.000000  ...                    0.000000
# max          15.000000  ...                    1.000000
#
#        property_type_Apartment  property_type_Bed_Breakfast  \
# count               3705.00000                  3705.000000
# mean                   0.45776                     0.009987
# std                    0.49828                     0.099446
# min                    0.00000                     0.000000
# 25%                    0.00000                     0.000000
# 50%                    0.00000                     0.000000
# 75%                    1.00000                     0.000000
# max                    1.00000                     1.000000
#
#        property_type_Condominium  property_type_House  property_type_Loft  \
# count                3705.000000          3705.000000         3705.000000
# mean                    0.024561             0.465047            0.010796
# std                     0.154805             0.498844            0.103356
# min                     0.000000             0.000000            0.000000
# 25%                     0.000000             0.000000            0.000000
# 50%                     0.000000             0.000000            0.000000
# 75%                     0.000000             1.000000            0.000000
# max                     1.000000             1.000000            1.000000
#
#        property_type_Townhouse  room_type_Entire_home_apt  \
# count              3705.000000                3705.000000
# mean                  0.031849                   0.665317
# std                   0.175621                   0.471943
# min                   0.000000                   0.000000
# 25%                   0.000000                   0.000000
# 50%                   0.000000                   1.000000
# 75%                   0.000000                   1.000000
# max                   1.000000                   1.000000
#
#        room_type_Private_room  room_type_Shared_room
# count             3705.000000            3705.000000
# mean                 0.304723               0.029960
# std                  0.460352               0.170499
# min                  0.000000               0.000000
# 25%                  0.000000               0.000000
# 50%                  0.000000               0.000000
# 75%                  1.000000               0.000000
# max                  1.000000               1.000000
#
# [8 rows x 44 columns]

# %%
#This code is run to fix the NAN Float error which we get when we run modelling 
data_dummies_ABB.fillna(999, inplace = True)

# %%
# Split the data into Train and Validation 
train_X =  data_dummies_ABB.drop("price", axis=1) #Drop the depedentend variable to start with
train_y = data_dummies_ABB.price
X_train, X_test, y_train, y_test = train_test_split(train_X,train_y,test_size = 0.2, random_state = 42)

# %%
lm_model = LinearRegression(normalize=True) # Instantiate LM by Normalizing the data to bring all data on same scale
# Fit the Linear model
lm_model.fit(X_train, y_train)
        
#Predict and score the model
y_test_preds = lm_model.predict(X_test)
y_train_preds = lm_model.predict(X_train)

# Calculate the r2 score, MAE, and MSE for the training data
r2_score_train_1=r2_score(y_train, y_train_preds)
mae_train=mean_absolute_error(y_train, y_train_preds)
mse_train=mean_squared_error(y_train, y_train_preds)

# Calculate the r2 score, MAE, and MSE for the test data
R_score=r2_score(y_test, y_test_preds)
mae_test=mean_absolute_error(y_test, y_test_preds)
mse_test=mean_squared_error(y_train, y_train_preds)
print("TRAINING:LINEAR_REGRESSION  model,the  r-squared={:.3f}, mae={:.3f}, mse={:.3f} on {} values.".format(r2_score_train_1, mae_train, mse_train, len(y_train)))
#"TESTING:The r-squared score for the LINEAR_REGRESSION  model was {} on {} values.".format(R_score, len(y_test))
"TESTING:LINEAR_REGRESSION  model,the  r-squared={:.3f}, mae={:.3f}, mse={:.3f} on {} values.".format(R_score, mae_test, mse_test, len(y_test))
# Out:
# TRAINING:LINEAR_REGRESSION  model,the  r-squared=0.580, mae=35.052, mse=3383.407 on 2964 values.
# 'TESTING:LINEAR_REGRESSION  model,the  r-squared=0.587, mae=35.056, mse=3383.407 on 741 values.'

# %%
lm_model=ensemble.RandomForestRegressor(n_estimators=350,criterion='mse',random_state=21,n_jobs=-1)
# Fit the selected model
lm_model.fit(X_train, y_train) 
# Predict and score the model 
y_test_preds_1 = lm_model.predict(X_test) 
y_train_preds_1 = lm_model.predict(X_train)
    
# Calculate the r2 score, MAE, and MSE for the training data
r2_score_train=r2_score(y_train, y_train_preds_1)
mae_train=mean_absolute_error(y_train, y_train_preds_1)
mse_train=mean_squared_error(y_train, y_train_preds_1)
    
# Calculate the r2 score, MAE, and MSE for the test data
r2_score_test=r2_score(y_test, y_test_preds_1)
mae_test=mean_absolute_error(y_test, y_test_preds_1)
mse_test=mean_squared_error(y_train, y_train_preds_1)

print("TRAINING:RANDOM_FOREST_REGRESSOR  model,the  r-squared={:.3f}, mae={:.3f}, mse={:.3f} on {} values.".format(r2_score_train, mae_train, mse_train, len(y_train)))
#"'TESTING:The r-squared score for the RANDOM_FOREST_REGRESSOR  model was {} on {} values.".format(r2_score_test, len(y_test))
"TESTING:RANDOM_FOREST_REGRESSOR  model ,The r-squared={:.3f}, mae={:.3f}, mse={:.3f} on {} values.".format(r2_score_test, mae_test, mse_test, len(y_test))
# Out:
# TRAINING:RANDOM_FOREST_REGRESSOR  model,the  r-squared=0.941, mae=12.509, mse=477.895 on 2964 values.
# 'TESTING:RANDOM_FOREST_REGRESSOR  model ,The r-squared=0.542, mae=33.817, mse=477.895 on 741 values.'

# %% [markdown]
# ### Visualizing Pricing Predictions

# %%
plt.figure(figsize=(12,8))
plt.scatter(y_test_preds,y_test,color='b', alpha = .5, label = 'Linear regression')
plt.scatter(y_test_preds_1,y_test,color='g', alpha = .35, label = 'Random Forests')
plt.xlabel('Predicted Price')
plt.ylabel('Actual Price')
plt.legend(loc='upper left')
plt.title("Predicted Prices vs. Actual Prices")

plt.show()

# %% [markdown]
# The figure above is a visualization of our predicted prices through both the Random Forests and linear Regression methods, our two best performing models.Predictions from both models look quite similar.

# %% [markdown]
# ## Visualizing Predictive Error

# %%
plt.figure(figsize=(12,8))
plt.scatter(y_train_preds,  y_train_preds - y_train,color='lightgreen', marker='o', label='Training data')
plt.scatter(y_test_preds,  y_test_preds - y_test,color='blue', marker='s', label='Test data')
plt.xlabel('Actual Price')
plt.ylabel('Error')
plt.title("Prediction Errors for Linear regression")
plt.legend(loc='upper left')
plt.show()

# %%
plt.figure(figsize=(12,8))
#plt.scatter(test_outcome,test_outcome - nn_grid.predict(test_features),color='b', alpha = .5, label = 'Linear regression')
#plt.scatter(test_outcome,test_outcome - rf_grid.predict(test_features),color='g', alpha = .35, label = 'Random Forests')
plt.scatter(y_train_preds_1,  y_train_preds_1 - y_train,color='lightgreen', marker='o', label='Training data')
plt.scatter(y_test_preds_1,  y_test_preds_1 - y_test,color='blue', marker='s', label='Test data')

plt.xlabel('Actual Price')
plt.ylabel('Error')
plt.title("Prediction Errors for Random Forest Regression")
plt.legend(loc='upper left')
plt.show()

# %%
bin_range = np.arange(0.0,200.0,10.0,dtype=np.float32)
fig = plt.figure(figsize=(8, 5))
ax = fig.add_subplot(111)    
arr = plt.hist(abs(y_test_preds_1 - y_test),bin_range,color='blue') 
your_bins=19
    
for i in range(your_bins):
    plt.text(arr[1][i],arr[0][i],'{0:.0f}'.format(arr[0][i]))
    
plt.title("Prediction Errors for Random Forest Regression")
plt.ylabel('Number of Data Points')
plt.xlabel('abs(prediction - actual)')
plt.xticks(bin_range)
plt.show()

# %%
bin_range = np.arange(0.0,200.0,10.0,dtype=np.float32)
fig = plt.figure(figsize=(8, 5))
ax = fig.add_subplot(111)    
arr = plt.hist(abs(y_test_preds - y_test),bin_range,color='blue') 
your_bins=19
    
for i in range(your_bins):
    plt.text(arr[1][i],arr[0][i],'{0:.0f}'.format(arr[0][i]))
    
plt.title("Prediction Errors for linear Regression")
plt.ylabel('Number of Data Points')
plt.xlabel('abs(prediction - actual)')
plt.xticks(bin_range)
plt.show()
